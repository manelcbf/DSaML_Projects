# %%
# Relevant Package Importing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
#Import Data from cluster.csv
db = pd.read_csv('cluster.csv')
db
# Out:
#          Churn                    Name Longevity  Year_Birth TypeTravel  \
# 0        churn       Ms. Nicole Clarke       yes      1974.0   business
# 1      nochurn         Mr. Jesse Scott       yes      1965.0   business
# 2        churn  Mr. Christopher Carter       yes      1973.0   business
# 3      nochurn     Ms. Jennifer Morgan       yes      1993.0    leisure
# 4      nochurn       Mr. Michael White       yes      1989.0   business
# ...        ...                     ...       ...         ...        ...
# 15584    churn       Ms. Wendy Roberts        no      1988.0   business
# 15585    churn         Ms. Sonya Smith        no      2000.0   business
# 15586  nochurn      Mr. Maxwell Wright       yes      1964.0   business
# 15587  nochurn       Mr. Gregory Moran       yes      1992.0    leisure
# 15588    churn       Mr. Steven Mendez       yes      1983.0   business
#
#       RoomType  RewardPoints  Comfort  ReceptionSchedule  FoodDrink  ...  \
# 0       single          4907        3                  4          1  ...
# 1       single          6724        1                  1          1  ...
# 2       single          4365        3                  3          3  ...
# 3       double          3849        1                  1          1  ...
# 4       single          5376        2                  2          3  ...
# ...        ...           ...      ...                ...        ...  ...
# 15584   double          4968        2                  0          2  ...
# 15585   double          4970        3                  3          3  ...
# 15586   single          4046        1                  1          1  ...
# 15587   double          5155        4                  3          4  ...
# 15588    suite          5136        3                  3          3  ...
#
#        Wifi  Amenities  Staff  OnlineBooking  PriceQuality  RoomSpace  \
# 0         4          3      4              3             3          3
# 1         5          3      4              5             5          5
# 2         1          4      4              3             3          2
# 3         4          4      5              4             4          4
# 4         5          5      5              5             5          3
# ...     ...        ...    ...            ...           ...        ...
# 15584     3          2      4              3             4          5
# 15585     5          3      5              5             3          1
# 15586     3          4      5              4             4          4
# 15587     5          4      5              5             2          5
# 15588     3          3      3              3             4          5
#
#        CheckOut  Checkin  Cleanliness  BarService
# 0             3        4            3           4
# 1             5        1            5           2
# 2             3        2            3           1
# 3             4        4            4           3
# 4             4        1            3           5
# ...         ...      ...          ...         ...
# 15584         1        3            4           3
# 15585         3        4            4           5
# 15586         4        5            4           4
# 15587         4        3            4           5
# 15588         4        1            3           3
#
# [15589 rows x 21 columns]

# %%
db[db['Year_Birth'].isna()]
# Out:
#          Churn                    Name Longevity  Year_Birth TypeTravel  \
# 27     nochurn        Ms. Emily Thomas       yes         NaN    leisure
# 126      churn     Ms. Elizabeth Tyler       yes         NaN   business
# 147    nochurn    Ms. Elizabeth Santos        no         NaN   business
# 168    nochurn    Ms. Elizabeth Lawson       yes         NaN   business
# 170    nochurn    Ms. Elizabeth Morgan       yes         NaN   business
# ...        ...                     ...       ...         ...        ...
# 15279  nochurn  Ms. Elizabeth Williams       yes         NaN    leisure
# 15302    churn      Mr. Edward Randall         y         NaN    leisure
# 15388  nochurn  Ms. Elizabeth Carrillo       yes         NaN   business
# 15445  nochurn    Ms. Elizabeth Wilson       yes         NaN   business
# 15568    churn    Ms. Elizabeth Barker        no         NaN   business
#
#       RoomType  RewardPoints  Comfort  ReceptionSchedule  FoodDrink  ...  \
# 27      double          4760        0                  5          0  ...
# 126     double          5151        2                  2          2  ...
# 147     single          5370        4                  4          4  ...
# 168     single          3669        1                  1          1  ...
# 170     single          4593        1                  1          1  ...
# ...        ...           ...      ...                ...        ...  ...
# 15279   double          5769        0                  4          0  ...
# 15302   double          4196        4                  5          5  ...
# 15388   single          6448        3                  3          3  ...
# 15445   single          5438        4                  4          5  ...
# 15568   single          4998        1                  4          1  ...
#
#        Wifi  Amenities  Staff  OnlineBooking  PriceQuality  RoomSpace  \
# 27        5          0      3              5             4          4
# 126       2          2      2              2             3          4
# 147       2          4      2              2             5          4
# 168       5          5      5              5             4          5
# 170       2          4      5              4             4          4
# ...     ...        ...    ...            ...           ...        ...
# 15279     3          4      1              2             2          0
# 15302     1          5      1              1             5          4
# 15388     4          5      4              5             5          5
# 15445     5          5      5              5             4          4
# 15568     5          1      5              5             1          2
#
#        CheckOut  Checkin  Cleanliness  BarService
# 27            5        4            4           5
# 126           3        2            4           2
# 147           4        4            4           2
# 168           5        4            4           5
# 170           5        2            4           4
# ...         ...      ...          ...         ...
# 15279         2        5            2           2
# 15302         4        3            4           1
# 15388         5        3            5           5
# 15445         5        4            4           5
# 15568         3        2            3           5
#
# [195 rows x 21 columns]

# %%
db[db['Year_Birth']>2006]
# Out:
#        Churn                  Name  Longevity  Year_Birth  TypeTravel  \
# 91      True   Ms. Bailey Johnston       True        2007       False
# 119     True    Ms. Jennifer Smith      False        2008        True
# 122    False      Mr. Justin Keith       True        2010       False
# 131     True     Ms. Summer Garcia      False        2011        True
# 141    False   Ms. Michelle Butler       True        2011       False
# ...      ...                   ...        ...         ...         ...
# 15489  False      Ms. Ashley Young       True        2007       False
# 15496   True   Mr. Brandon Rosales       True        2008       False
# 15544   True      Ms. Robin Bailey       True        2007       False
# 15556  False      Ms. Angela Brown       True        2011       False
# 15567  False  Ms. Jennifer Harrell       True        2007       False
#
#       RoomType  RewardPoints  Comfort  ReceptionSchedule  FoodDrink  ...  \
# 91      double          5611        4                  2          4  ...
# 119     double          4504        2                  2          2  ...
# 122     double          4642        4                  4          4  ...
# 131     double          5133        1                  2          2  ...
# 141     single          5353        4                  4          4  ...
# ...        ...           ...      ...                ...        ...  ...
# 15489    suite          4302        2                  2          2  ...
# 15496   double          4733        4                  5          4  ...
# 15544   double          5332        3                  5          3  ...
# 15556   double          5544        5                  5          5  ...
# 15567   double          5640        5                  5          5  ...
#
#        Wifi  Amenities  Staff  OnlineBooking  PriceQuality  RoomSpace  \
# 91        1          4      1              1             1          2
# 119       1          2      1              1             1          1
# 122       1          4      1              1             4          5
# 131       1          2      1              1             1          3
# 141       4          4      4              5             5          4
# ...     ...        ...    ...            ...           ...        ...
# 15489     2          4      5              5             5          5
# 15496     4          2      2              5             4          1
# 15544     4          3      2              4             3          4
# 15556     5          2      5              4             4          4
# 15567     4          5      4              4             1          3
#
#        CheckOut  Checkin  Cleanliness  BarService
# 91            2        3            1           1
# 119           4        1            3           1
# 122           5        5            4           1
# 131           3        3            2           1
# 141           5        3            5           3
# ...         ...      ...          ...         ...
# 15489         5        5            5           3
# 15496         1        2            3           2
# 15544         5        3            5           4
# 15556         4        2            4           5
# 15567         2        5            2           4
#
# [813 rows x 21 columns]

# %%
#Import Data from cluster.csv
db = pd.read_csv('cluster.csv')
db[db.duplicated(keep = False)]
db.drop_duplicates(inplace = True)
# Changing NA values to median value of year and converting to int32
db['Year_Birth'] = db['Year_Birth'].fillna(db['Year_Birth'].median()).astype(int).astype(np.int16)
db['RewardPoints'] = db['RewardPoints'].fillna(db['RewardPoints'].median()).astype(np.int16)
# Converting every column that is int64 to int8 for performance issues
db.iloc[:,(db.dtypes=='int64').values] = db.iloc[:,(db.dtypes=='int64').values].astype(np.int8)
# Change longevity y to yes
db['Longevity'] = db['Longevity'].replace('y','yes')
# Churn, Longevity can be boolean for performence issues
db['Longevity']=db['Longevity'].map({'yes': True, 'no': False})
db['Churn']=db['Churn'].map({'churn': True, 'nochurn': False})
db['TypeTravel']=db['TypeTravel'].map({'business': True, 'leisure': False})
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15586 entries, 0 to 15588
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Churn              15586 non-null  bool
#  1   Name               15586 non-null  object
#  2   Longevity          15586 non-null  bool
#  3   Year_Birth         15586 non-null  int16
#  4   TypeTravel         15586 non-null  bool
#  5   RoomType           15586 non-null  object
#  6   RewardPoints       15586 non-null  int16
#  7   Comfort            15586 non-null  int8
#  8   ReceptionSchedule  15586 non-null  int8
#  9   FoodDrink          15586 non-null  int8
#  10  Location           15586 non-null  int8
#  11  Wifi               15586 non-null  int8
#  12  Amenities          15586 non-null  int8
#  13  Staff              15586 non-null  int8
#  14  OnlineBooking      15586 non-null  int8
#  15  PriceQuality       15586 non-null  int8
#  16  RoomSpace          15586 non-null  int8
#  17  CheckOut           15586 non-null  int8
#  18  Checkin            15586 non-null  int8
#  19  Cleanliness        15586 non-null  int8
#  20  BarService         15586 non-null  int8
# dtypes: bool(3), int16(2), int8(14), object(2)
# memory usage: 684.9+ KB

# %%
def describe(db, stats):
    d = db.describe()
    return d.append(db.reindex(d.columns, axis = 1).agg(stats))

describe(db, ['skew', 'mad', 'kurt']).T
# Out:
#                      count         mean          std     min     25%     50%  \
# Year_Birth         15586.0  1981.696779    15.084697  1936.0  1970.0  1981.0
# RewardPoints       15586.0  5022.418581  1027.940126   409.0  4445.0  5088.0
# Comfort            15586.0     2.841332     1.388541     0.0     2.0     3.0
# ReceptionSchedule  15586.0     2.997049     1.519035     0.0     2.0     3.0
# FoodDrink          15586.0     2.844412     1.436937     0.0     2.0     3.0
# Location           15586.0     2.985821     1.299438     1.0     2.0     3.0
# Wifi               15586.0     3.244963     1.327064     0.0     2.0     3.0
# Amenities          15586.0     3.374631     1.352419     0.0     2.0     4.0
# Staff              15586.0     3.506288     1.319625     1.0     3.0     4.0
# OnlineBooking      15586.0     3.454190     1.310401     0.0     2.0     4.0
# PriceQuality       15586.0     3.459579     1.268180     1.0     3.0     4.0
# RoomSpace          15586.0     3.470871     1.293782     0.0     2.0     4.0
# CheckOut           15586.0     3.700500     1.158693     1.0     3.0     4.0
# Checkin            15586.0     3.327409     1.266944     1.0     3.0     3.0
# Cleanliness        15586.0     3.692288     1.154484     1.0     3.0     4.0
# BarService         15586.0     3.347427     1.300371     0.0     2.0     3.0
#
#                        75%     max      skew         mad      kurt
# Year_Birth         1994.00  2014.0 -0.001992   12.501188 -0.701207
# RewardPoints       5648.75  6950.0 -0.453744  794.589753  0.260162
# Comfort               4.00     5.0 -0.100806    1.169587 -0.935490
# ReceptionSchedule     4.00     5.0 -0.260518    1.283631 -1.077415
# FoodDrink             4.00     5.0 -0.123543    1.211755 -0.967006
# Location              4.00     5.0 -0.050057    1.058767 -1.076634
# Wifi                  4.00     6.0 -0.171105    1.147335 -1.111382
# Amenities             4.00     5.0 -0.599424    1.145487 -0.540790
# Staff                 5.00     5.0 -0.554468    1.133386 -0.859138
# OnlineBooking         5.00     5.0 -0.472109    1.133048 -0.931961
# PriceQuality          4.00     5.0 -0.503290    1.080928 -0.772889
# RoomSpace             5.00     5.0 -0.482872    1.118398 -0.864568
# CheckOut              5.00     5.0 -0.750667    0.944841 -0.225208
# Checkin               4.00     5.0 -0.382822    1.064593 -0.812148
# Cleanliness           5.00     5.0 -0.745109    0.941758 -0.225374
# BarService            4.00     5.0 -0.358340    1.113287 -0.949633

# %%
db.loc[:,'Comfort':'BarService'].mode()
# Out:
#    Comfort  ReceptionSchedule  FoodDrink  Location  Wifi  Amenities  Staff  \
# 0        3                  4          3         3     4          4      4
#
#    OnlineBooking  PriceQuality  RoomSpace  CheckOut  Checkin  Cleanliness  \
# 0              4             4          4         4        4            4
#
#    BarService
# 0           4

# %%
sns.histplot(db['Wifi'], color="g")
# Out:
# <AxesSubplot:xlabel='Wifi', ylabel='Count'>

# %%
db[db['Wifi']==6]['TypeTravel'].value_counts(normalize=True)
# Out:
# True     0.666667
# False    0.333333
# Name: TypeTravel, dtype: float64

# %%
db[['Wifi','TypeTravel']].value_counts()
# Out:
# Wifi  TypeTravel
# 4     True          2581
# 5     True          2399
# 3     True          2319
# 2     True          2268
# 1     True          1157
# 4     False         1122
# 5     False         1046
# 3     False         1028
# 2     False          977
# 1     False          635
# 6     True            24
# 0     False           12
# 6     False           12
# 0     True             6
# dtype: int64

# %%
db[db.loc[:,'Comfort':'BarService'].apply(lambda x:min(x)==max(x),1)]
# Out:
#          Churn               Name Longevity  Year_Birth TypeTravel RoomType  \
# 1548   nochurn   Mr. Marcus Burns       yes      1981.0   business   single
# 6707     churn  Ms. Anna Caldwell       yes      2004.0   business   single
# 15259  nochurn  Mr. Randy Robbins       yes      1976.0   business   single
#
#        RewardPoints  Comfort  ReceptionSchedule  FoodDrink  ...  Wifi  \
# 1548           5289        4                  4          4  ...     4
# 6707           1689        4                  4          4  ...     4
# 15259          6699        5                  5          5  ...     5
#
#        Amenities  Staff  OnlineBooking  PriceQuality  RoomSpace  CheckOut  \
# 1548           4      4              4             4          4         4
# 6707           4      4              4             4          4         4
# 15259          5      5              5             5          5         5
#
#        Checkin  Cleanliness  BarService
# 1548         4            4           4
# 6707         4            4           4
# 15259        5            5           5
#
# [3 rows x 21 columns]

# %%
bookme_corr = db.corr(method = 'spearman') # use spearman correlation

# unsupervised learning (k-means) - columns with high correlation (> 0.7 approximately) -> some of them should be removed

figure = plt.figure(figsize=(16,10))
sns.heatmap(bookme_corr, annot=True, fmt = '.1g')
# Out:
# <AxesSubplot:>

# %%
nochurn = db[db['Churn']==False]
nochurn[['Cleanliness']].value_counts(normalize=True)
# Out:
# Cleanliness
# 4              0.400354
# 5              0.364012
# 3              0.111386
# 2              0.077522
# 1              0.046726
# dtype: float64

# %%
nochurn = db[db['Churn']==True]
nochurn[['Cleanliness']].value_counts(normalize=True)
# Out:
# Cleanliness
# 4              0.344115
# 3              0.281254
# 5              0.162143
# 2              0.132893
# 1              0.079595
# dtype: float64

# %%
#db['Year_Birth'].corr(db['RoomType'])
nochurn = db[db['Churn']==False].corr(method = 'spearman')
figure = plt.figure(figsize=(16,10))
sns.heatmap(nochurn, annot=True, fmt = '.1g')
# Out:
# <AxesSubplot:>

# %%
#db['Year_Birth'].corr(db['RoomType'])
nochurn = db[db['Churn']==True].corr(method = 'spearman')
figure = plt.figure(figsize=(16,10))
sns.heatmap(nochurn, annot=True, fmt = '.1g')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Exploration
#
# - Longevity with yes, no, y: change y to yes.
# - Wifi has values of 6: the percentage of people who choose 6 among leisure/business (31% vs 69%) is in line with the general percentage of leisure/business (33% vs 67%). 0 and 6 are the two less choosen options. The order of prefered choice is the same for leisure and business.
# - Changing the data type of Churn, Longevity and TypeTravel in order to correlate with the other variables shows only Churn-Amenities has a correlation greater than abs(0.5) --> value -0.6. Churn also has an abs(0.4) correlation with Staff and OnlineBooking. The other two never pass beyond abs(0.3).
# - There are 3 rows that gave the same classification to every aspect (1548, 6707, 15259), two gave all 4 and the other all 5. All roomtype single, business and longevity = yes.
#
#
#
#
# #### To Explore
# - From the start, the only Attribute with missing non-null values is Year_Birth. For storytelling purposes, we should discuss how to explore the narrative here for median vs mode vs mean
#
# - Include in storytelling the type of clients that use all 0 or all 5. Also, check the type of clients that use 1 instead of 0, does that make sense? Is check in and Check out necessary?
#
# - Check how many repeat visits do we have from the potential customers. (Name)

# %% [markdown]
# Heatmap Churn/noChurn com leisure/business com RoomType --> Diferencial entre total e parcial
# KNN imputer - missing values TODO
